# %% [markdown]
# 1. FOR RUNNING THE PROGRAM WE NEED A SOFTWARE KNOW COMPLIER OR INTERPRETER
# 2. FOR WRITING A PROGRAM WE NEED IDE(PYCHARM)

# %% [markdown]
# CODE ==> IDE==>Interprete/compile==>Byte_code==>PVM==>OUTPUT==>IDE

# %%
'''Python is a genaral PURPOSE programming language (ex. solving problem ,automate)
python is a high level programming language .
Developed by GUIDO VAN ROSSAM in 1989 , working in national institute of Netherland .
but officially python was launched in feb 20 , 1991 .
this is the first programming language for beginner
python is open source ==> anyone can modify it '''
# Out:
# 'Python is a genaral PURPOSE programming language (ex. solving problem ,automate)\npython is a high level programming language .\nDeveloped by GUIDO VAN ROSSAM in 1989 , working in national institute of Netherland .\nbut officially python was launched in feb 20 , 1991 .\nthis is the first programming language for beginner\npython is open source ==> anyone can modify it '

# %% [markdown]
# **how guido has written the python**

# %%
# 1. functional programming features from c language.
# 2. oop features from C++.
# 3. scripting language feature from perl ans shall .
# 4. Modular programming from modula-3 .
# 5. most of the syntax from c and ABC.

# %% [markdown]
# ### features of python

# %%
# 1. python is simple and easy
# 2. freeware and open source
# 3. high level programming language 
# 4. platform independent .
# 5. portable  
# 6. dynamically typed language 
# 7. procedure oriented "c" and object oriented "c++"
# 8. interpreted language
# 9. extensible (with python we can use other programming language )
# 10. embeded language
# 11. extensive library

# %% [markdown]
# ### flavours of python

# %%
# c + python = cpython
# c + python = cython
# java + python = jython
# python + python = pypython
# anaconda + python = anacondapython

# %% [markdown]
# ### version of python

# %%
# python 1.0 v - jan 1994
# python 2.0 v - oct 2000
# python 3.0 v - dec 2008
