# %% [markdown]
# # TUPLE

# %% [raw]
# tuple is similar to list , except it is mutable . once we create a tuple , we cannot modify it.

# %% [markdown]
# ## *conditions for a tuple*

# %% [markdown]
# - 1.insertion order is preserved
# - 2.duplicates are allowed
# - 3.heterogenuous objects are allowed
# - 4.we use () to store the elemens and to separate ","

# %% [markdown]
# ## defining a tuple

# %% [raw]
# tuple can be defined with or without ()

# %%
t=10,20,30

# %%
t
# Out:
# (10, 20, 30)

# %%
type(t)
# Out:
# tuple

# %%
t=()
t
type(t)
# Out:
# tuple

# %%
t=(10,)

# %%
type(t)
# Out:
# tuple

# %%
t=()
t=10
t=10,
t=(10,)
t=10,20,30,
t=(10,20,30)

# %%
tu=("suuny","bunny","funny")

# %%
type(tu)
# Out:
# tuple

# %%
#  tuple to list
list=["suuny","bunny","funny"]
p=tuple(list)

# %%
p
# Out:
# ('suuny', 'bunny', 'funny')

# %%
t=tuple(range(0,50,3))

# %%
t
# Out:
# (0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48)

# %% [markdown]
# # accessing the elements of a tuple

# %% [markdown]
# ### 1.by indexing

# %% [markdown]
#  t=(10,20,50,40,8)

# %%
t[0]
# Out:
# 10

# %%
t[4]
# Out:
# 8

# %% [markdown]
# ### 2. by slicing operator

# %%
t=10,20,30,40,50,60,70,80,90

# %%
t[0:5]
# Out:
# (10, 20, 30, 40, 50)

# %%
t[0:8:2]
# Out:
# (10, 30, 50, 70)

# %% [markdown]
# # mathematical operators in tuple

# %% [markdown]
# - concatination (+)
# - repetation (*)

# %%
t1=10,20,30

# %%
t2=50,40,60

# %%
t1+t2
# Out:
# (10, 20, 30, 50, 40, 60)

# %%
t1*3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %% [markdown]
# # comparision operator

# %%
t1=10,20,30
t2=40,50,60

# %%
t1==t2
# Out:
# False

# %%
t1>t2
# Out:
# False

# %%
t1<t2
# Out:
# True

# %% [markdown]
# # functions in tuple

# %% [markdown]
# ### len()

# %%
t=10,20,30,40,50,60

# %%
len(t)
# Out:
# 6

# %% [markdown]
# ### count()

# %%
t=10,20,30,40,50,60,10,20,10,20

# %%
t.count(10)
# Out:
# 3

# %% [markdown]
# ### index()

# %%
t=10,20,30,40,50,60,10,20,10,20

# %%
t.index(20)
# Out:
# 1

# %% [markdown]
# ### sorted()

# %%
k=(30,40,10,50,60,10,20)

# %%
sorted(k)
# Out:
# [10, 10, 20, 30, 40, 50, 60]

# %%
k
# Out:
# (30, 40, 10, 50, 60, 10, 20)

# %%
p=("a","d","k","b","f","e")

# %%
sorted(p)
# Out:
# ['a', 'b', 'd', 'e', 'f', 'k']

# %% [markdown]
# ### difference between sort and sorted

# %% [markdown]
# - sort() : method that modifies the original list
# - sorted() : built in function thar returns a new sorted list without changing the original one

# %% [markdown]
# ### min() and max()

# %%
t=10,50,60,40,80

# %%
min(t)
# Out:
# 10

# %%
t=855,655,422,321,952

# %%
max(t)
# Out:
# 952

# %% [markdown]
# # tuple packing and unpacking

# %%
a=10
b=20
c=30
d=40
t=a,b,c,d
t
# Out:
# (10, 20, 30, 40)

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# #### tuple unpacking

# %%
y=(50,90,60,71)

# %%
 x,y,z,w = y

# %%
x,y,z,w
# Out:
# (50, 90, 60, 71)

# %%
w
# Out:
# 71

# %% [markdown]
# ### differences between list and tuple

# %% [markdown]
# - list mutable , tuple immutable
# - [] , ()
# - sort () & sorted() , only sorted()
# - growable in nature , read only mode of list
