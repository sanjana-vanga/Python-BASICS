# %% [markdown]
# # DATA TYPES

# %% [markdown]
# data type represent the type of data present inside a variable

# %% [markdown]
# in python we are not required to specify the type explicitly

# %% [markdown]
# based on the value provided , the type will be assigned automatically

# %% [markdown]
# *i.e  python is dynamically type language*

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
# no of built in data types in python

# %% [markdown]
# - int
#  : numbers
#   -4 , -3 , -5

# %% [markdown]
# # five fundamental data types

# %% [markdown]
# - 1. int = number
# - 2. float = decimal
# - 3. str = character
# - 4. complex = combination of real and imaginary values : 4+6k
# - 5. bool = true/false

# %% [markdown]
# # composite data type

# %% [markdown]
# 1. bytes = 0-255 (256)
# 2. bytearray (formate will change)
# 3. range
# 4. list
# 5. tuple
# 6. set
# 7. frozenset
# 8. dictionary

# %% [markdown]
# # int data type

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a
# Out:
# 10

# %% [markdown]
# ### we can represent int in multiple format

# %% [markdown]
# 1. binary (base : 2)
# 2. decimal(base :10)
# 3. octal(base:8)
# 4. hexa decimal(base:16)

# %%
binary = 0b11
decimal = 1000
octal = 0o456
hexa  = 0XA69

# %%
binary
# Out:
# 3

# %%
decimal
# Out:
# 1000

# %%
octal
# Out:
# 302

# %%
hexa
# Out:
# 2665

# %% [markdown]
# ### decimal to all

# %%
a=1000

# %%
bin(a),oct(a),hex(a)
# Out:
# ('0b1111101000', '0o1750', '0x3e8')

# %% [markdown]
# ### binary to all

# %%
b=0b111100

# %%
b, oct(b),hex(b)
# Out:
# (60, '0o74', '0x3c')

# %% [markdown]
# ### octal to all

# %%
c =0o2435

# %%
c, bin(c),hex(c)
# Out:
# (1309, '0b10100011101', '0x51d')

# %% [markdown]
# ### hex to all

# %%
d=0xAB568

# %%
d,bin(d),oct(d)
# Out:
# (701800, '0b10101011010101101000', '0o2532550')

# %% [markdown]
# # float

# %%
a=13.56

# %%
type(a)
# Out:
# float

# %% [markdown]
# # complex

# %%
 x=6+8j

# %%
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 6.0

# %%
x.imag
# Out:
# 8.0

# %% [markdown]
# # string

# %%
name = 'hemanth'
name2="boini"

# %%
name
# Out:
# 'hemanth'

# %%
name2
# Out:
# 'boini'

# %%
my_name = '''durga
prasad
yadav'''

# %%
my_name
# Out:
# 'durga\nprasad\nyadav'

# %% [markdown]
# # writing comment in python

# %% [markdown]
# 1. using # you can write the comment
# 2. using 'comment' you can write the comment
# 3. using "comment" you can write the comment
# 4. using ''' comment ''' for multiline

# %% [markdown]
# ### bool

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=20

# %%
b=30

# %%
a is b
# Out:
# False

# %%
id(a)
# Out:
# 140721467074056

# %%
id(b)
# Out:
# 140721467074376

# %%
a is not b
# Out:
# True
