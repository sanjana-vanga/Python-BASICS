# %% [markdown]
# # dictionary

# %%
key:"value"

# %% [markdown]
# ###### *key should be unique , values can be duplicate*

# %% [markdown]
# - 1.if we need to represent the data in one as object and other as the feature of the object we use dictionary .

# %% [markdown]
# - dose not preserver insertion order
# - duplicates are allowed only in values
# - it is mutable
# - dynamic
# - indexing and slicing is not applicable

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
t=dict()

# %%
type(d)
# Out:
# dict

# %%
d[20]="sunny"
d[10]="funny"
d[50]="bunny"

# %%
d
# Out:
# {20: 'sunny', 10: 'funny', 50: 'bunny'}

# %%
type(d)
# Out:
# dict

# %%
d={"key":"pair"}

# %% [markdown]
# ### accessing the data from the dictionary

# %%
d={100:"abhi",200:"rahul",300:"raju",400:"ishan"}

# %%
d[100]
# Out:
# 'abhi'

# %%
d[400]="hemanth"

# %%
d
# Out:
# {100: 'abhi', 200: 'rahul', 300: 'raju', 400: 'hemanth'}

# %%
d[100]="gill"

# %%
d
# Out:
# {100: 'gill', 200: 'rahul', 300: 'raju', 400: 'hemanth'}

# %% [markdown]
# ### deleting the element :del()

# %%
d={100:"abhi",200:"rahul",300:"raju",400:"ishan"}

# %%
del d[100]

# %%
d
# Out:
# {200: 'rahul', 300: 'raju', 400: 'ishan'}

# %% [markdown]
# ### clear()

# %%
d.clear()

# %%
d
# Out:
# {}

# %% [markdown]
# ## functions of dict

# %% [markdown]
# #### dict() :used to create empty dictionary

# %%
d=dict()

# %%
d=dict({1:"apple",2:"mango",3:"kiwi"})

# %%
d
# Out:
# {1: 'apple', 2: 'mango', 3: 'kiwi'}

# %%
len(d)
# Out:
# 3

# %% [markdown]
# #### get()

# %%
d=dict({1:"apple",2:"mango",3:"kiwi"})

# %%
d.get(3)
# Out:
# 'kiwi'

# %% [markdown]
# #### pop() : delete an element

# %%
d.pop(1)
# Out:
# 'apple'

# %%
d
# Out:
# {2: 'mango', 3: 'kiwi'}

# %% [markdown]
# #### popitem() : *used to delete last inserted element*

# %%
d={"blue":"sky","red":"blood","sky":"blue"}

# %%
d.popitem()
# Out:
# ('sky', 'blue')

# %%
d
# Out:
# {'blue': 'sky', 'red': 'blood'}

# %% [markdown]
# #### return associated keys with each dictionary

# %%
d={1:"10th",2:"12th",3:"degree"}

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
for i in d.keys():
    print(i)
# Out:
# 1
# 2
# 3

# %%
d.values()
# Out:
# dict_values(['10th', '12th', 'degree'])

# %% [markdown]
# #### copy() : creates a duplicate

# %%
d1=d.copy()

# %%
d1
# Out:
# {1: '10th', 2: '12th', 3: 'degree'}

# %%
#  write a program to take dictionary as input and get the sum

# %%
d=eval(input("enter one dictionary"))
s=sum(d.values())
print(s)
# Out:
# enter one dictionary {"a":100,"b":300}
# 400
