# %% [markdown]
# - operators are symbols that perform some operations
# - there are many types of operators in python

# %% [markdown]
# - 1. arithmetic operator
# - 2. relational operator/comparision operator
# - 3. logical operator
# - 4. bitwise operator
# - 5. assignment operator
# - 6. special operator

# %% [markdown]
# # 1. arithematic operator

# %% [raw]
# + addition
# - subtraction
# // floor division (only integer value , no decimals)
# ** power
# * multiplication
# / division
# % modulo (remainder)

# %%
a=10
b=2

# %%
print("sum" ,a+b)
print("difference" ,a-b)
print("product" ,a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# sum 12
# difference 8
# product 20
# 5.0
# 0
# 5
# 100

# %%
#code for finding out even or odd

# %%
a=63
if a % 2==0:
    print("even")
else :
    print("odd")
# Out:
# odd

# %% [markdown]
# a=20

# %%
print(a/3)
# Out:
# 3.3333333333333335

# %% [markdown]
# # 2. relational operator

# %% [raw]
# > , >= , < , <=

# %%
a=50
b=50
print(a > b )
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %% [markdown]
# # 3. equality operator

# %% [raw]
# == , !=

# %%
10==10
# Out:
# True

# %%
10==20
# Out:
# False

# %%
"dayakar"=="dayakar"
# Out:
# True

# %%
n=13
if n

# %% [markdown]
# # 3. logical operator

# %% [raw]
# and ,or, not
#
# and=if both arguments are True then only result is True
# or=if atleast one  arguments is True then only result is True
# not=not  True meaning False ,  False is True

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
10 and 20
# Out:
# 20

# %%
#x and y
#if x is evaluated to False return x otherwise y .

# %%
0 and 20
# Out:
# 0

# %%
20 and 10
# Out:
# 10

# %%
#x or y
#if x is evaluated to True then result is x otherwise y

# %%
10 or 20
# Out:
# 10

# %%
0 or 10
# Out:
# 10

# %%
not 10
# Out:
# False

# %% [markdown]
# # 4.bitwise operator

# %% [raw]
# - this operator can be used with integer or bool
#
# & , |, ^ , << , >>

# %% [markdown]
# #### condition

# %% [markdown]
# - & if both bits are 1 then only result is 1 otherwise result is 0 .

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(5)
# Out:
# '0b101'

# %%
print(4&5)
# Out:
# 4

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(15)
# Out:
# '0b1111'

# %%
print(10&15)
# Out:
# 10

# %% [markdown]
# - | if atleast one bit is 1 then result is 1 otherwise 0

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(15)
# Out:
# '0b1111'

# %%
print(10|15)
# Out:
# 15

# %% [markdown]
# - ^ if bits are different then only the result is 1 , otherwise 0

# %%
bin(30)
# Out:
# '0b11110'

# %%
bin(20)
# Out:
# '0b10100'

# %%
print(30^20)
# Out:
# 10

# %% [markdown]
# -   ">> " bitwise right shift operator

# %%
print(10>>2)
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %% [markdown]
# -   "<< " bitwise left shift operator

# %%
bin(10<<2)
# Out:
# '0b101000'

# %% [markdown]
# # assignment operator

# %%
#we can use assignment operator to assign value to the variable

# %%
a=10 #a carries the value 10

# %%
#now you can combine assignment operator with some other operator to compound assignment operator

# %%
a+=10 #a=a+10

# %%
a
# Out:
# 20

# %%
a+=10

# %%
a
# Out:
# 20

# %%
# +=
# -=
# *=
# /=

# %% [markdown]
# # ternary operator

# %% [raw]
# x=first value if condition else second value
# if condition is True then first value will be consider else second value

# %%
a=10
b=20
x=30 if a<b else 40
x
# Out:
# 30

# %%
a=10
b=20
x=30 if a>b else 40
x
# Out:
# 40

# %%
#taking input from keyboard and print minimum value

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
min=a if a<b else b
min
# Out:
# enter the first number 20
# enter the second number 15
# 15

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
c=int(input("enter the third number"))
min=a if a<b and a<c else b
min=b if b<c  else c
min
# Out:
# enter the first number 20
# enter the second number 30
# enter the third number 10
# 10

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
c=int(input("enter the third number"))
mini=a if a<b and a<c else b if b<a and b<c else c
mini
# Out:
# enter the first number 15
# enter the second number 10
# enter the third number 5
# 5

# %%
#taking input from keyboard and print max value

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
c=int(input("enter the third number"))
max=a if a>b and a>c else b if b>a and b>c else c
max
# Out:
# enter the first number 20
# enter the second number 25
# enter the third number 50
# 50

# %% [markdown]
# # special operator

# %% [raw]
# there are two operators in python

# %% [raw]
# 1. identity operator
# 2. membership operator

# %% [markdown]
# ### 1. identity operator

# %% [markdown]
# 1. identity operator
# we can identify operators for address comparision
#  #there are two identity operators
# - is
# -  is not

# %%
a=10
b=30

# %%
a is b
# Out:
# False

# %%
a=10
b=10

# %%
a is b
# Out:
# True

# %%
a=20
b=30

# %%
a is not b
# Out:
# True

# %%
id(a)
# Out:
# 140721427097096

# %%
id(b)
# Out:
# 140721427097416

# %%
a=5+8j
id(a)
# Out:
# 2833070614864

# %%
b=5+8j
id(b)
# Out:
# 2833070614608

# %%
a is not b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a="hemanth"

# %%
id (a)
# Out:
# 2833061416512

# %%
b="hemanth"

# %%
a is b
# Out:
# True

# %%
list1=["one","two","three"]

# %%
list2=["one","two","three"]

# %%
list1 is list2
# Out:
# False

# %%
id(list1)
# Out:
# 2833070758464

# %%
id(list2)
# Out:
# 2833071028032

# %%
list1==list2
# Out:
# True

# %% [markdown]
# ### 2. membership operator

# %% [raw]
# in => returns true if the given object present in the specified collection
# not in => returns true if the given object  is not present in the specified collection

# %%
x="learning python is very easy !"

# %%
'l' in x
# Out:
# True

# %%
'z' not in x
# Out:
# True

# %%
list1=["sunny","bunny","funny","chinni","pinni"]

# %%
'pinni' in list1
# Out:
# True

# %%
'sunny' not in list1
# Out:
# False

# %% [markdown]
# # operator precedence

# %% [raw]
# if multiple operator present then which operator will be evaluated first that will be decide by operator precedence.

# %%
3+5*4
# Out:
# 23

# %%
66+845-(632/23)
# Out:
# 883.5217391304348

# %% [raw]
# -> () paranthesis
# -> ** exponential
# -> ~,- bitwise
# -> * , / , % ,//
# -> +,-
# -> <<,>>
# -> bitwise end
