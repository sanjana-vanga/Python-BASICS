# %% [markdown]
# converting one data type to others

# %% [markdown]
# ## int - float,int -complex,int -str,int -bool

# %%
a=100

# %%
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 100.0

# %%
str(a)
# Out:
# '100'

# %%
complex(a)
# Out:
# (100+0j)

# %%
bool(a)
# Out:
# True

# %% [markdown]
# ## float-int,float-complex,float-str,float-bool

# %%
b=12.60

# %%
int(b)
# Out:
# 12

# %%
str(b)
# Out:
# '12.6'

# %%
complex(b)
# Out:
# (12.6+0j)

# %%
bool(b)
# Out:
# True

# %% [markdown]
# ## string
# - can't be converted into int
# - can't be converted into float
# - can't be converted into complex

# %%
name = "rakshith"

# %%
bool(name)
# Out:
# True

# %%
d= ""

# %%
bool (d)
# Out:
# False

# %% [markdown]
# ## complex-
# - can't be converted into int
# - can't be converted into float

# %%
com=7+8j

# %%
str(com)
# Out:
# '(7+8j)'

# %%
bool(com)
# Out:
# True
